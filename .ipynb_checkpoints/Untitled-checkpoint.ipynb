# %%
import matplotlib.pyplot as plt
import pandas as pd
img = pd.read_csv("../../../data/continuous1/001/training/EOG_001_01_001.csv",names=["vertical","horizontal"])
plt.plot(range(len(img["vertical"])),img["vertical"])
plt.plot(range(len(img["vertical"])),img["horizontal"])
plt.savefig(str("try.png"))
