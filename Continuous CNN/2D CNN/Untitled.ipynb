# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
with open("./modelimgresult.pck", "rb") as input_file:
    img = pickle.load(input_file)

# %%
for i in img:
    print(i)
# Out:
# parameter
# cross_val
# result

# %%
plt.plot(range(len(img["result"][0]["val_acc"])),img["result"][0]["train_acc"])
plt.plot(range(len(img["result"][0]["val_acc"])),img["result"][0]["val_acc"])
